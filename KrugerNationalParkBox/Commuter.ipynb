# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

from pyproj import Geod
from shapely.geometry import MultiPoint
from shapely.geometry import Point, LineString, Polygon

import contextily as ctx

# %%
df = pd.read_csv('./bin/Debug/net5.0/Commuter.csv')
ids = list(df['ID'].unique())

# %%
ids
# Out:
# ['57da5d8a-cff4-4712-94de-ad1289cd78fc',
#  '5e53fcb6-ee2d-4d1e-907f-aaa76080b0d0',
#  '71f1f4f9-cb30-4909-854b-5e7c7d2e2011',
#  '9d563fd1-7d10-494d-bcb7-0c7b2ffee73f',
#  'f8b09902-dd92-4289-b638-6f6b5ecdca0b']

# %%
df2 = df[df['ID'] == ids[0]]

# %%
df2['CarVelocity'].plot(x='Tick')
# Out:
# <AxesSubplot:>

# %%
df2.to_csv('tmp.csv', index=False)

# %%
fig, ax = plt.subplots(figsize=(16, 5))



for i in ids:
    df2  = df[df['ID'] == i]
    ax.plot(df2['Tick'], df2['CarVelocity'], label=i)



plt.xlabel('Tick')
plt.ylabel('m/s')
# Out:
# Text(0, 0.5, 'm/s')
